# %%
import pandas as pd

y = pd.Period('2026')
y
# Out:
# Period('2026', 'Y-DEC')

# %%
y.start_time
# Out:
# Timestamp('2026-01-01 00:00:00')

# %%
y.end_time
# Out:
# Timestamp('2026-12-31 23:59:59.999999999')

# %%
#Monthly Period
monthly = pd.Period('2026-1',freq='M')
monthly
# Out:
# Period('2026-01', 'M')

# %%
monthly.start_time
# Out:
# Timestamp('2026-01-01 00:00:00')

# %%
monthly+1
# Out:
# Period('2026-02', 'M')

# %%
#Daily Period
day = pd.Period('2026-01-01',freq='D')
day
# Out:
# Period('2026-01-01', 'D')

# %%
#Quarterly Period
quarter = pd.Period('2026Q1', freq='Q-DEC')

# %%
quarter
# Out:
# Period('2026Q1', 'Q-DEC')

# %%
indx = pd.period_range(start='2025',periods=4,freq='Q-DEC')
indx
# Out:
# PeriodIndex(['2025Q1', '2025Q2', '2025Q3', '2025Q4'], dtype='period[Q-DEC]')

# %%
df = pd.DataFrame({
    'Revenue':[1200,3444,5667,234],
    'Quarter': pd.period_range(start='2025',periods=4,freq='Q-DEC')
    })

# %%
df
# Out:
#         Revenue
# 2025Q1     1200
# 2025Q2     3444
# 2025Q3     5667
# 2025Q4      234
