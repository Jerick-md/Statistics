# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import LinearRegression
from mathplotlib.pyplot import mathplotlib as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 3
#       1 import pandas as pd
#       2 import seaborn as sns
# ----> 3 from sklearn.model_selection import LinearRegression
#       4 from mathplotlib.pyplot import mathplotlib as plt
#
# ImportError: cannot import name 'LinearRegression' from 'sklearn.model_selection' (C:\Users\acer\AppData\Roaming\Python\Python313\site-packages\sklearn\model_selection\__init__.py)

# %%
df = pd.read_csv('data.csv')
